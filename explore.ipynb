# %%
import pandas as pd
import numpy as np
import seaborn as sns
import statistics
import math
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")
# %matplotlib inline

# %%
data_prepared = pd.read_csv("PreparedData.csv")

# %%
plt.figure(figsize = (21,10))
data_prepared["Close"].plot()
# Out:
# <AxesSubplot:>

# %%
data_prepared.describe()
# Out:
#               Open         High          Low        Close        Volume  \
# count  2770.000000  2770.000000  2770.000000  2770.000000  2.770000e+03
# mean     31.860089    32.192432    31.528051    31.873388  2.866399e+08
# std      24.853383    25.189297    24.510128    24.864564  2.289079e+08
# min       5.882910     5.993919     5.818078     5.873125  4.544800e+07
# 25%      15.302906    15.481824    15.195129    15.346521  1.211217e+08
# 50%      24.857039    25.113631    24.569916    24.791560  2.030340e+08
# 75%      41.326661    41.681158    41.071280    41.346448  3.889732e+08
# max     137.029595   137.764116   133.347011   135.679626  1.880998e+09
#
#          Dividends  Stock Splits         5dma        10dma   vol_change  \
# count  2770.000000   2770.000000  2766.000000  2761.000000  2769.000000
# mean      0.001814      0.003971    31.818726    31.751357     0.056056
# std       0.016741      0.153161    24.712919    24.528919     0.385199
# min       0.000000      0.000000     5.950739     5.974011    -0.712266
# 25%       0.000000      0.000000    15.272625    15.244372    -0.188370
# 50%       0.000000      0.000000    24.835810    24.984441    -0.018342
# 75%       0.000000      0.000000    41.233021    41.176081     0.214728
# max       0.205000      7.000000   132.997607   130.663985     5.090526
#
#         pct_change   volatility       Target
# count  2769.000000  2770.000000  2769.000000
# mean      0.124940     0.019563     0.519321
# std       1.782931     0.012260     0.499717
# min     -12.864700     0.004138     0.000000
# 25%      -0.694737     0.011895     0.000000
# 50%       0.097018     0.016714     1.000000
# 75%       1.042141     0.023842     1.000000
# max      11.980820     0.232439     1.000000

# %%
plt.figure(figsize = (12,4))
sns.boxplot(data_prepared['Close'])
# Out:
# <AxesSubplot:xlabel='Close'>

# %%
plt.figure(figsize = (12,8))
sns.histplot(data_prepared["Close"], bins=50)
# Out:
# <AxesSubplot:xlabel='Close', ylabel='Count'>

# %%
plt.figure(figsize = (15,15))
sns.heatmap(data_prepared.corr())
# Out:
# <AxesSubplot:>
